# %%
# '돈이 있으면 택시를 타고 가고, 돈이 없으면 걸어간다.'
money = True
# 만약에 money = 참 이면 택시타고 가고 아니면 걸어간다
# if 조건:
if money:
    print('택시 타고 간다')
else:
    print('걸어 간다.')
# Out:
# 택시 타고 간다

# %%
x = 3
y = 2
print(x >= y)
# Out:
# True

# %%
# money in my pocket

1 in [1,2,3]
1 not in [1,2,3]
# Out:
# False

# %%
num = int(input('숫자를 하나 입력하세요'))

if num == 3:
    print('동일하다')
else:
    print('다른 숫자다')
# Out:
# 숫자를 하나 입력하세요 3
# 동일하다

# %%
num = input('입력 (,로 구분하세요) : ')
num.split(',')
print(num)

# 1,2,3,4,5,6
# num.split(',')
# if '1' in num:
#     print(1)
# else:
#     print(2)
# Out:
# 입력 (,로 구분하세요) :  1,2,3,4,5,6
# 1,2,3,4,5,6

# %%
name = input('이름을 입력하세요 : ')
age = int(input('나이를 입력하세요 : '))
school = input('다니는 학교를 입력하세요 : ')

print(f'저의 이름은 name, age살, school 다니고 있습니다.')
# Out:
# 이름을 입력하세요 :  d
# 나이를 입력하세요 :  d
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 name = input('이름을 입력하세요 : ')
# ----> 2 age = int(input('나이를 입력하세요 : '))
#       3 school = input('다니는 학교를 입력하세요 : ')
#       5 print(f'저의 이름은 name, age살, school 다니고 있습니다.')
#
# ValueError: invalid literal for int() with base 10: 'd'
