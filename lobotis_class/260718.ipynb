# %%
리스트 = ['a', 'b', 'c']
print(리스트[1])
리스트.append('라면')
print(리스트)
리스트.remove('a')
print(리스트)
# Out:
# b
# ['a', 'b', 'c', '라면']
# ['b', 'c', '라면']

# %%
사전 = {'ㄱ':'a', 'ㄴ':'b', 'ㄷ':'c'}
print(사전['ㄷ'])
사전['야구']='오타니'
print(사전)
사전['ㄱ']='ㅋㅋ'
print(사전)
# Out:
# c
# {'ㄱ': 'a', 'ㄴ': 'b', 'ㄷ': 'c', '야구': '오타니'}
# {'ㄱ': 'ㅋㅋ', 'ㄴ': 'b', 'ㄷ': 'c', '야구': '오타니'}

# %%
음식 = input('입력하세요')
음식.split(',')

if '3' in 음식:
    print('지금먹자')
else:
    print('끓이자')
# Out:
# 입력하세요 3,4,5
# 지금먹자

# %%
id =  'robotiz'
pw = 'codeium'

id = input('아이디를 입력하세요')
pw = input('패스워드를 입력하세요')

if id == 'robotiz' and pw == 'codeium':
    print('로그인 성공!')
else:
    print('아이디, 비번 잘못됨')
# Out:
# 아이디를 입력하세요 robotiz
# 패스워드를 입력하세요 codeium
# 로그인 성공!

# %%
num = int(input('숫자 입력'))

if num % 2 == 1:
    print('홀수')
else:
    print('짝수')
# Out:
# 숫자 입력 4
# 짝수

# %%
온도 = int(input('온도'))
습도 = int(input('습도'))

if 온도 >= 30 and 습도 >= 60:
    print('덥고 습함')
elif 온도 >= 30 or 습도 >= 60:
    print('덥거나 습함')
else:
    print(zho
# Out:
# 0.5
